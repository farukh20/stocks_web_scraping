# %%
import yfinance as yf

# Get the data
data_1d = yf.download(tickers=['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA', 'IBM', 'NFLX', 'INTC', 'NVDA', 'AMD', 'DIS', 'META', 'GS', 'JPM', 'V', 'BORR', 'KOS', 'COST', 'QTUM', 'CAT'],period="12mo", interval="1d")

# Print the data
print(data_1d.tail())
# Out:
# [*********************100%%**********************]  20 of 20 completed
#              Adj Close                                                         \
#                   AAPL         AMD        AMZN   BORR         CAT        COST
# Date
# 2023-12-28  193.580002  148.759995  153.380005  7.310  296.880005  663.099976
# 2023-12-29  192.529999  147.410004  151.940002  7.310  295.670013  660.080017
# 2024-01-02  185.639999  138.580002  149.929993  7.320  292.709991  650.650024
# 2024-01-03  184.250000  135.320007  148.470001  7.300  284.299988  644.690002
# 2024-01-04  181.664993  136.279999  146.259995  7.225  286.994995  646.252319
#
#                                                            ...    Volume  \
#                   DIS       GOOGL          GS         IBM  ...      INTC
# Date                                                       ...
# 2023-12-28  90.400002  140.229996  386.410004  163.750000  ...  27705200
# ...

# %%
import yfinance as yf

# Get the data
data_1wk = yf.download(tickers=['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA', 'IBM', 'NFLX', 'INTC', 'NVDA', 'AMD', 'DIS', 'META', 'GS', 'JPM', 'V', 'BORR', 'KOS', 'COST', 'QTUM', 'CAT'],period="12mo", interval="1wk")

# Print the data
print(data_1wk.tail())
# Out:
# [*********************100%%**********************]  20 of 20 completed
#              Adj Close                                                \
#                   AAPL         AMD        AMZN      BORR         CAT
# Date
# 2023-12-04  195.710007  128.919998  147.419998  6.138016  259.500000
# 2023-12-11  197.570007  139.149994  149.970001  6.962378  285.739990
# 2023-12-18  193.600006  139.600006  153.419998  7.230544  290.359985
# 2023-12-25  192.529999  147.410004  151.940002  7.310000  295.670013
# 2024-01-01  181.667603  136.279999  146.309998  7.225000  286.989990
#
#                                                                        ...  \
#                   COST        DIS       GOOGL          GS         IBM  ...
# Date                                                                   ...
# 2023-12-04  597.199524  92.518471  134.990005  350.829987  161.960007  ...
# 2023-12-11  644.171326  93.459999  132.600006  380.510010  162.229996  ...
# ...

# %%
import yfinance as yf

# Get the data
data_1mo = yf.download(tickers=['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA', 'IBM', 'NFLX', 'INTC', 'NVDA', 'AMD', 'DIS', 'META', 'GS', 'JPM', 'V', 'BORR', 'KOS', 'COST', 'QTUM', 'CAT'],period="12mo", interval="1mo")

# Print the data
print(data_1mo.tail())
# Out:
# [*********************100%%**********************]  20 of 20 completed
#              Adj Close                                                \
#                   AAPL         AMD        AMZN      BORR         CAT
# Date
# 2023-09-01  170.984741  102.820000  127.120003  7.051766  271.596619
# 2023-10-01  170.545319   98.500000  133.089996  6.088356  224.887970
# 2023-11-01  189.700073  121.160004  146.089996  6.257201  250.720001
# 2023-12-01  192.529999  147.410004  151.940002  7.310000  295.670013
# 2024-01-01  181.690002  136.259903  146.300095  7.225000  286.972412
#
#                                                                        ...  \
#                   COST        DIS       GOOGL          GS         IBM  ...
# Date                                                                   ...
# 2023-09-01  551.386353  80.786713  130.860001  320.934662  138.726685  ...
# 2023-10-01  539.167114  81.324951  124.080002  301.137207  143.018005  ...
# ...

# %%
import yfinance as yf

# Get the data
data_3mo = yf.download(tickers=['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA', 'IBM', 'NFLX', 'INTC', 'NVDA', 'AMD', 'DIS', 'META', 'GS', 'JPM', 'V', 'BORR', 'KOS', 'COST', 'QTUM', 'CAT'],period="12mo", interval="3mo")

# Print the data
print(data_3mo.tail())
# Out:
# [*********************100%%**********************]  20 of 20 completed
#              Adj Close                                                \
#                   AAPL         AMD        AMZN      BORR         CAT
# Date
# 2023-01-01  163.983398   98.010002  103.290001  7.528505  224.249207
# 2023-04-01  193.186340  113.910004  130.360001  7.478845  242.263870
# 2023-07-01  170.754166  102.820000  127.120003  7.051766  270.258240
# 2023-10-01  192.276688  147.410004  151.940002  7.310000  294.150085
# 2024-01-01  181.718994  136.259995  146.353302  7.225000  287.059998
#
#                                                                        ...  \
#                   COST        DIS       GOOGL          GS         IBM  ...
# Date                                                                   ...
# 2023-01-01  482.170898  99.804726  103.730003  317.061127  124.887436  ...
# 2023-04-01  523.362488  88.989975  119.699997  314.870056  129.044586  ...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
def extract_comments(stock):
  url = f'https://finance.yahoo.com/quote/{stock}/community?p={stock}'
  response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/110.0'})
  soup = BeautifulSoup(response.text)
  data = json.loads(soup.select_one('#spotim-config').get_text(strip=True))['config']

  url = "https://api-2-0.spot.im/v1.0.0/conversation/read"
  payload = json.dumps({
    "conversation_id": data['spotId'] + data['uuid'].replace('_', '$'),
    "count": 250,
    "offset": 0
  })
  headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/110.0',
    'Content-Type': 'application/json',
    'x-spot-id': data['spotId'],
    'x-post-id': data['uuid'].replace('_', '$'),
  }

  response = requests.post(url, headers=headers, data=payload)
  data = response.json()
  list_rep = data['conversation']['comments']
  count = 0
  for i in range(0,10):
    dict = list_rep[i]
    cont = dict['content'][0]
    if count == 10 :
      break

    if 'text' in cont :
      count = count+1
      print(cont['text'])

# %%
tickers=['AAPL', 'GOOGL', 'AMZN', 'MSFT', 'TSLA', 'IBM', 'NFLX', 'INTC', 'NVDA', 'AMD', 'DIS', 'META', 'GS', 'JPM', 'V', 'BORR', 'KOS', 'COST', 'CAT']
for ticker in tickers :
  print(ticker)
  print('\n')
  print('\n')
  extract_comments(ticker)
  print('\n')
  print('\n')
# Out:
# AAPL
#
#
#
#
# <p>china took apples technology selling the same cell phone for $200 game over</p>
# no wonder more than 12 top apple executives left apple ...speaks volumes
# <p>china took apples technology selling the same cell phone for $200 game over</p>
# there is so much dirt hiding unde apple ...people are getting bold to come up and stand up against stinking apple and it&#39;s pathetic culture.
# <p>We need some truly NEW products...not just tweaks of those that thave been around since Steve Jobs.  Losing phone sales to those whose phones are as good and WAY LESS expensive.  Need some actual innovation.  Need to consider looking for a new CEO.  We&#39;ve lost about $160 Billion in market value over the past two days.</p>
# apple settles law suit for being accomplished to criminal activity over iTunes scam....how much more pathetic this company can be ...shame on all the apple big investors...they have lost all respect
# I’ve got a limit order in at 180. Good time to buy.
# ...
